# %% [markdown]
# # LOAD DATA

# %%
import pandas as pd
import matplotlib.pyplot as plt
crime = pd.read_csv("Crime_Data_from_2020_to_Present.csv")

# %% [markdown]
# # Understand and Clean the Data

# %%
crime.head()
# Out:
#    division_number date_reported        date_occurred  area    area_name  \
# 0         10304468    2020-01-08  2020-01-08 22:30:00     3    Southwest
# 1        190101086    2020-01-02  2020-01-01 03:30:00     1      Central
# 2        200110444    2020-04-14  2020-02-13 12:00:00     1      Central
# 3        191501505    2020-01-01  2020-01-01 17:30:00    15  N Hollywood
# 4        191921269    2020-01-01  2020-01-01 04:15:00    19      Mission
#
#    reporting_district  part  crime_code  \
# 0                 377     2         624
# 1                 163     2         624
# 2                 155     2         845
# 3                1543     2         745
# 4                1998     2         740
#
#                                    crime_description  modus_operandi  ...  \
# 0                           BATTERY - SIMPLE ASSAULT       0444 0913  ...
# 1                           BATTERY - SIMPLE ASSAULT  0416 1822 1414  ...
# ...

# %%
crime.columns
# Out:
# Index(['division_number', 'date_reported', 'date_occurred', 'area',
#        'area_name', 'reporting_district', 'part', 'crime_code',
#        'crime_description', 'modus_operandi', 'victim_age', 'victim_sex',
#        'victim_descent', 'premise_code', 'premise_description', 'weapon_code',
#        'weapon_description', 'status', 'status_description', 'crime_code_1',
#        'crime_code_2', 'crime_code_3', 'crime_code_4', 'location',
#        'cross_street', 'latitude', 'longitude'],
#       dtype='object')

# %%
# Melihat ada berapa banyak baris/rows dan kolom di datanya
crime.shape
# Out:
# (852950, 27)

# %%
# Data Types dari setiap datanya
crime.dtypes
# Out:
# division_number          int64
# date_reported           object
# date_occurred           object
# area                     int64
# area_name               object
# reporting_district       int64
# part                     int64
# crime_code               int64
# crime_description       object
# modus_operandi          object
# victim_age               int64
# victim_sex              object
# victim_descent          object
# premise_code           float64
# premise_description     object
# weapon_code            float64
# weapon_description      object
# status                  object
# status_description      object
# crime_code_1           float64
# crime_code_2           float64
# crime_code_3           float64
# crime_code_4           float64
# location                object
# cross_street            object
# latitude               float64
# longitude              float64
# dtype: object

# %%
# Check Nulls
crime.isna().sum()
# Out:
# division_number             0
# date_reported               0
# date_occurred               0
# area                        0
# area_name                   0
# reporting_district          0
# part                        0
# crime_code                  0
# crime_description           0
# modus_operandi         118311
# victim_age                  0
# victim_sex             112606
# victim_descent         112614
# premise_code               10
# premise_description       518
# weapon_code            556202
# weapon_description     556202
# status                      0
# status_description          0
# crime_code_1               11
# crime_code_2           790429
# crime_code_3           850837
# crime_code_4           852888
# location                    0
# cross_street           717289
# latitude                    0
# longitude                   0
# dtype: int64

# %%
df = crime.drop(labels = ['modus_operandi', 'weapon_code', 'weapon_description',
                          'crime_code_2', 'crime_code_3', 'crime_code_4', 'cross_street'], axis = 1)
df
# Out:
#         division_number date_reported        date_occurred  area    area_name  \
# 0              10304468    2020-01-08  2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02  2020-01-01 03:30:00     1      Central
# 2             200110444    2020-04-14  2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01  2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01  2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                  ...   ...          ...
# 852945        231606525    2023-03-22  2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12  2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02  2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05  2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10  2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
df.sort_values(by = 'date_reported')
# Out:
#         division_number date_reported        date_occurred  area    area_name  \
# 39025         201004026    2020-01-01  2020-01-01 18:23:00    10  West Valley
# 137157        202100503    2020-01-01  2020-01-01 13:15:00    21      Topanga
# 2389          200304056    2020-01-01  2020-01-01 14:37:00     3    Southwest
# 103594        201804032    2020-01-01  2020-01-01 12:50:00    18    Southeast
# 25891         200104434    2020-01-01  2020-01-01 02:50:00     1      Central
# ...                 ...           ...                  ...   ...          ...
# 770235        230125557    2023-12-04  2023-12-04 06:50:00     1      Central
# 692345        231917421    2023-12-04  2023-12-03 09:45:00    19      Mission
# 835683        232117291    2023-12-04  2023-03-01 12:00:00    21      Topanga
# 825607        231116467    2023-12-04  2023-12-01 22:30:00    11    Northeast
# 676338        231116462    2023-12-04  2023-11-17 12:00:00    11    Northeast
#
# ...

# %%
# Mengubah data types yang dari Object ke dalam bentuk DateTime
#Update datatypes
df['date_reported'] = pd.to_datetime(df['date_reported'], format = '%Y-%m-%d')
df['date_occurred'] = pd.to_datetime(df['date_occurred'])

# %%
df.dtypes
# Out:
# division_number                 int64
# date_reported          datetime64[ns]
# date_occurred          datetime64[ns]
# area                            int64
# area_name                      object
# reporting_district              int64
# part                            int64
# crime_code                      int64
# crime_description              object
# victim_age                      int64
# victim_sex                     object
# victim_descent                 object
# premise_code                  float64
# premise_description            object
# status                         object
# status_description             object
# crime_code_1                  float64
# location                       object
# latitude                      float64
# longitude                     float64
# dtype: object

# %%
# Fungsi describe ini mengambil ringkasan dari nilai-nilai dalam bentuk perhitungan tertentu seperti count, mean, min, max dll.
df.describe(include = ['float64', 'int64'])
# Out:
#        division_number           area  reporting_district           part  \
# count     8.529500e+05  852950.000000       852950.000000  852950.000000
# mean      2.166969e+08      10.707354         1117.165490       1.412575
# std       1.100081e+07       6.097178          609.716073       0.492298
# min       8.170000e+02       1.000000          101.000000       1.000000
# 25%       2.102184e+08       6.000000          615.000000       1.000000
# 50%       2.202184e+08      11.000000         1141.000000       1.000000
# 75%       2.301094e+08      16.000000         1617.000000       2.000000
# max       2.399306e+08      21.000000         2199.000000       2.000000
#
#           crime_code     victim_age   premise_code   crime_code_1  \
# count  852950.000000  852950.000000  852940.000000  852939.000000
# mean      500.746338      29.742191     305.974292     500.486350
# std       207.705242      21.799470     216.950442     207.493864
# ...

# %%
# Disini kita mengambil jumlah setiap orang yang punya umur tertentu dalam data 
# Fungsi value counts ini misalkan kita mau menghitung jumlah tipe kejahatan tertentu contoh :
# tipe A,B,C,D didata tersebut ada berapa banyak yang termasuk tipe A B C D berdasarkan jumlah kemunculannya
df['victim_age'].value_counts()
# Out:
# victim_age
#  0      211842
#  30      19421
#  35      19008
#  31      18603
#  29      18552
#          ...
#  97         63
# -1          60
# -2          13
#  120         1
# -3           1
# Name: count, Length: 103, dtype: int64

# %%
# Kita memastikanvictim age lebih dari 0
df_age = df[df['victim_age'] > 0]

# %%
# Kita count lagi yang jumlah age nya > 0
df_age['victim_age'].value_counts()
# Out:
# victim_age
# 30     19421
# 35     19008
# 31     18603
# 29     18552
# 28     18266
#        ...
# 95        89
# 96        88
# 98        67
# 97        63
# 120        1
# Name: count, Length: 99, dtype: int64

# %%
# Membuat column baru khusus 'Year' dan juga 'Month'
df['year'] = df['date_occurred'].dt.year
df['month'] = df['date_occurred'].dt.month

# %%
# Kita urutkan berdasarkan date nya
# Disini bisa kita lihat data reported crime nya berhenti apda '2023-12-04'
# Artinya pada bulan 12 data crime nya sudah berhenti di laporkan 
df.sort_values(by = 'date_reported')
# Out:
#         division_number date_reported       date_occurred  area    area_name  \
# 39025         201004026    2020-01-01 2020-01-01 18:23:00    10  West Valley
# 137157        202100503    2020-01-01 2020-01-01 13:15:00    21      Topanga
# 2389          200304056    2020-01-01 2020-01-01 14:37:00     3    Southwest
# 103594        201804032    2020-01-01 2020-01-01 12:50:00    18    Southeast
# 25891         200104434    2020-01-01 2020-01-01 02:50:00     1      Central
# ...                 ...           ...                 ...   ...          ...
# 770235        230125557    2023-12-04 2023-12-04 06:50:00     1      Central
# 692345        231917421    2023-12-04 2023-12-03 09:45:00    19      Mission
# 835683        232117291    2023-12-04 2023-03-01 12:00:00    21      Topanga
# 825607        231116467    2023-12-04 2023-12-01 22:30:00    11    Northeast
# 676338        231116462    2023-12-04 2023-11-17 12:00:00    11    Northeast
#
# ...

# %% [markdown]
# # Feature Understanding

# %%
df['month'].value_counts()
# Out:
# month
# 10    75464
# 7     75429
# 8     75072
# 5     73349
# 1     73129
# 6     72891
# 9     72141
# 3     71196
# 4     70299
# 11    69960
# 2     68679
# 12    55341
# Name: count, dtype: int64

# %%
df['month'].value_counts().sort_index()
# Out:
# month
# 1     73129
# 2     68679
# 3     71196
# 4     70299
# 5     73349
# 6     72891
# 7     75429
# 8     75072
# 9     72141
# 10    75464
# 11    69960
# 12    55341
# Name: count, dtype: int64

# %%
# Kita menampilkan dalam grafik count jumlah data dari setiap bulannya yang di sort dari bulan 1-12
# Bisa kita lihat pada bulan 12 terjadi penurunan tingkat crime dalam grafik karena jika kita melihat
# nilai dari data crime yang sebelumnya di sort berdasarkan date_reported, data reported nya berhenti pada bulan 12  tanggal 4
df['month'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='month'>

# %%
df['year'].value_counts()
# Out:
# year
# 2022    234436
# 2023    209581
# 2021    209451
# 2020    199482
# Name: count, dtype: int64

# %%
df['year'].value_counts().sort_index()
# Out:
# year
# 2020    199482
# 2021    209451
# 2022    234436
# 2023    209581
# Name: count, dtype: int64

# %%
# Kita urutkan dan tampilkan dalam grafik data crime nya pada setiap tahun 
# Dari 2020 -2023, dapat kita lihat dari grafik kemunculan crime di tahun 2022 adalah yang tertinggi
# dan tahin 2020 adalah yang terendah
df['year'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
df = df[~((df['month'] == 12) & (df['year'] == 2023))]

# %%
df.sort_values(by = 'date_occurred')
# Out:
#         division_number date_reported       date_occurred  area   area_name  \
# 168264        201810982    2020-05-11 2020-01-01 00:01:00    18   Southeast
# 196441        220706832    2022-03-16 2020-01-01 00:01:00     7    Wilshire
# 1559          210708670    2021-05-11 2020-01-01 00:01:00     7    Wilshire
# 199361        221818077    2022-09-28 2020-01-01 00:01:00    18   Southeast
# 129124        201704365    2020-01-02 2020-01-01 00:01:00    17  Devonshire
# ...                 ...           ...                 ...   ...         ...
# 672120        230717815    2023-12-01 2023-11-30 23:45:00     7    Wilshire
# 766816        230917064    2023-12-04 2023-11-30 23:48:00     9    Van Nuys
# 770137        230221843    2023-12-01 2023-11-30 23:50:00     2     Rampart
# 726894        231116332    2023-12-01 2023-11-30 23:50:00    11   Northeast
# 743649        232018618    2023-12-01 2023-11-30 23:59:00    20     Olympic
#
#         reporting_district  part  crime_code  \
# ...

# %%
crime_over_time = df.groupby(['year', 'month']).size()
crime_over_time
# Out:
# year  month
# 2020  1        18496
#       2        17255
#       3        16165
#       4        15683
#       5        17204
#       6        17034
#       7        17121
#       8        16874
#       9        15639
#       10       16491
#       11       15574
#       12       15946
# 2021  1        16552
#       2        15411
#       3        16320
#       4        16057
#       5        16989
#       6        17156
#       7        18659
#       8        18374
#       9        18362
#       10       19305
#       11       18340
#       12       17926
# 2022  1        18448
#       2        17700
#       3        19687
#       4        19784
#       5        20418
#       6        20201
#       7        19952
#       8        20081
#       9        19279
#       10       20274
#       11       18688
#       12       19924
# 2023  1        19633
#       2        18313
#       3        19024
#       4        18775
#       5        18738
#       6        18500
# ...

# %%
# Kita menampilkan dalam grafik dimana data nya digabungkan berdasarkan tahun dan juga bulan 
# Dan kita dapat melihat grafik data crime nya disetiap tahun dan bulan tertentu
crime_over_time = df.groupby(['year', 'month']).size().plot()
crime_over_time
# Out:
# <Axes: xlabel='year,month'>

# %%
# Kita menampilkan dalam bentuk histogram data victim age yang ada
plt.hist(df_age['victim_age'], edgecolor = 'black', bins = 15)
# Out:
# (array([3.96800e+03, 1.86630e+04, 9.81120e+04, 1.44858e+05, 1.22469e+05,
#         8.64850e+04, 7.20760e+04, 4.59690e+04, 2.94150e+04, 1.28000e+04,
#         4.50300e+03, 1.27400e+03, 4.41000e+02, 0.00000e+00, 1.00000e+00]),
#  array([  2.        ,   9.86666667,  17.73333333,  25.6       ,
#          33.46666667,  41.33333333,  49.2       ,  57.06666667,
#          64.93333333,  72.8       ,  80.66666667,  88.53333333,
#          96.4       , 104.26666667, 112.13333333, 120.        ]),
#  <BarContainer object of 15 artists>)

# %%
# Membuat column baru yang tidak memiliki time atau jam hanya sampai pada date nya
df['date_occurred_no_time'] = df['date_occurred'].dt.date

# %%
df
# Out:
#         division_number date_reported       date_occurred  area    area_name  \
# 0              10304468    2020-01-08 2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02 2020-01-01 03:30:00     1      Central
# 2             200110444    2020-04-14 2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01 2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01 2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                 ...   ...          ...
# 852945        231606525    2023-03-22 2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12 2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02 2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05 2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10 2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
# Disini kita menghitung jumlah crime pada setiap harinya dan didalamnya crime apa yang dilakukan
# jadi disini kita groupby date kemunculan setiap tanggal nya dan crime description nya

crime_count_per_day = df.groupby(['date_occurred_no_time', 'crime_description']).size()
crime_count_per_day
# Out:
# date_occurred_no_time  crime_description
# 2020-01-01             ARSON                                                        4
#                        ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT              47
#                        ATTEMPTED ROBBERY                                            5
#                        BATTERY - SIMPLE ASSAULT                                    74
#                        BATTERY POLICE (SIMPLE)                                      5
#                                                                                    ..
# 2023-11-30             VEHICLE - ATTEMPT STOLEN                                     3
#                        VEHICLE - STOLEN                                            51
#                        VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, BIKES, ETC)     2
#                        VIOLATION OF COURT ORDER                                     2
# ...

# %%
# Disini kita mengambil data top 20 crime yang terjadi berdasarkan tipe setiap crime nya / crime descriptionnya
# kita juga menampilkan average_daily_count nya dari setiap tipe crime tersebut

top_20_crimes = crime_count_per_day.groupby('crime_description').mean()\
                    .reset_index(name = 'average_daily_count').sort_values(by = 'average_daily_count', ascending = False).head(20)
top_20_crimes
# Out:
#                                      crime_description  average_daily_count
# 132                                   VEHICLE - STOLEN            63.830769
# 4                             BATTERY - SIMPLE ASSAULT            47.432168
# 115                                  THEFT OF IDENTITY            37.331469
# 21                               BURGLARY FROM VEHICLE            36.718182
# 20                                            BURGLARY            36.260839
# 129  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...            36.185315
# 2       ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT            34.114685
# 117                 THEFT PLAIN - PETTY ($950 & UNDER)            30.306993
# 73                   INTIMATE PARTNER - SIMPLE ASSAULT            29.833566
# 113    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)            22.954545
# 112  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...            21.452448
# ...

# %%
# Kita urutkan secara ascending (kecil ke besar) berdasarkan data "average_daily_count" nya

top_20_crimes_sorted = top_20_crimes.sort_values(by = 'average_daily_count', ascending = True)
top_20_crimes_sorted
# Out:
#                                      crime_description  average_daily_count
# 135                     VIOLATION OF RESTRAINING ORDER             7.517870
# 72               INTIMATE PARTNER - AGGRAVATED ASSAULT             8.104269
# 127                                        TRESPASSING             8.578322
# 15                                     BRANDISH WEAPON             9.252448
# 38              CRIMINAL THREATS - NO WEAPON DISPLAYED            12.313986
# 104           SHOPLIFTING - PETTY THEFT ($950 & UNDER)            14.421678
# 130           VANDALISM - MISDEAMEANOR ($399 OR UNDER)            15.772727
# 122  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...            19.558741
# 99                                             ROBBERY            20.374126
# 112  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...            21.452448
# 113    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)            22.954545
# ...

# %%
# Kita tampilkan dalam grafik bar plot dari crime description dan jumlah rata" kejadian setiap harinya
plt.barh(top_20_crimes_sorted['crime_description'], top_20_crimes_sorted['average_daily_count'])
# Out:
# <BarContainer object of 20 artists>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
plt.figure(figsize = (12,8))

#Plot 1 - Line Chart
plt.subplot(2,2,1)
crime_plot = df.groupby(['year', 'month']).size().plot(color='green', linewidth=2)
crime_plot.set_xlabel('Year - Month', fontsize=10)
crime_plot.set_title('Crime over Time')

#Plot 2 - Histogram
plt.subplot(2,2,2)
plt.hist(df_age['victim_age'], edgecolor = 'black', bins = 15)
plt.tight_layout()
plt.xlabel('Age', fontsize = 10)
plt.title('Distribution of Victim Age')

# #Plot 3 - Horizontal Bar
plt.figure()
plt.barh(top_20_crimes_sorted['crime_description'], top_20_crimes_sorted['average_daily_count'], color = 'orange')
plt.title('Top 20 Crimes')
# Out:
# Text(0.5, 1.0, 'Top 20 Crimes')

# %%
# Kita disini ingin menampilkan bagaimana jarak dari sebuah kasus itu terjadi dan samapi dia di laporkan
# Show difference in reported and occured - How long it takes to report?
df['Time to report'] = (pd.to_datetime(df['date_reported']) - pd.to_datetime(df['date_occurred_no_time'])).dt.days

# %%
df
# Out:
#         division_number date_reported       date_occurred  area    area_name  \
# 0              10304468    2020-01-08 2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02 2020-01-01 03:30:00     1      Central
# 2             200110444    2020-04-14 2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01 2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01 2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                 ...   ...          ...
# 852945        231606525    2023-03-22 2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12 2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02 2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05 2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10 2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
# Kita menampilkan data setiap time to report nya ada berapa data
# Misalkan untuk time to report yang selama 0 days ada berapa, 2 days ada berapa dll.
df['Time to report'].value_counts().head(10)
# Out:
# Time to report
# 0    419620
# 1    185029
# 2     52808
# 3     30894
# 4     19932
# 5     14416
# 6     10837
# 7      9722
# 8      7053
# 9      5660
# Name: count, dtype: int64

# %%
# Kita menampilkan data yang digabungkan dari setiap crime description dan time to reportnya
# Jadi disini kita menampilkan data jumlah rata" nilai penggabungan setiap crime description dan time to reportnya
# Jadi misalkan data crime description "BOMB SCARE" punya rata" time to reportnya berapa lama

df.groupby(['crime_description'])['Time to report'].mean().sort_values().head(10)
# Out:
# crime_description
# FAILURE TO DISPERSE                                         0.000000
# DISRUPT SCHOOL                                              0.083333
# PURSE SNATCHING - ATTEMPT                                   0.083333
# PETTY THEFT - AUTO REPAIR                                   0.125000
# LYNCHING                                                    0.157895
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                    0.250000
# BOMB SCARE                                                  0.345960
# BATTERY POLICE (SIMPLE)                                     0.371023
# FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)          0.400000
# REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR DISTRIBUTE)    0.500000
# Name: Time to report, dtype: float64

# %%
df_age.groupby('crime_description')['victim_age'].mean()
# Out:
# crime_description
# ARSON                                                       45.087953
# ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER                31.385246
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT              38.081001
# ATTEMPTED ROBBERY                                           39.142931
# BATTERY - SIMPLE ASSAULT                                    40.571314
#                                                               ...
# VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, BIKES, ETC)    33.993271
# VIOLATION OF COURT ORDER                                    42.609982
# VIOLATION OF RESTRAINING ORDER                              43.052366
# VIOLATION OF TEMPORARY RESTRAINING ORDER                    43.152278
# WEAPONS POSSESSION/BOMBING                                  36.714286
# Name: victim_age, Length: 136, dtype: float64

# %%
# Fungsi reset_index pada Pandas digunakan untuk mengatur ulang indeks DataFrame ke urutan default 
# (0, 1, 2, ...). Indeks lama dapat dijadikan kolom baru atau dibuang.

df_age.groupby('crime_description')['victim_age'].mean().reset_index()
# Out:
#                                      crime_description  victim_age
# 0                                                ARSON   45.087953
# 1         ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER   31.385246
# 2       ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT   38.081001
# 3                                    ATTEMPTED ROBBERY   39.142931
# 4                             BATTERY - SIMPLE ASSAULT   40.571314
# ..                                                 ...         ...
# 131  VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, B...   33.993271
# 132                           VIOLATION OF COURT ORDER   42.609982
# 133                     VIOLATION OF RESTRAINING ORDER   43.052366
# 134           VIOLATION OF TEMPORARY RESTRAINING ORDER   43.152278
# 135                         WEAPONS POSSESSION/BOMBING   36.714286
#
# [136 rows x 2 columns]

# %%
# Identify the top 3 crimes with the highest average victim age
# Menampilkan top 3 crimes dengan rata" tertinggi victim age atau usia korban rata"

df_age.groupby('crime_description')['victim_age'].mean().reset_index().sort_values(by = 'victim_age', ascending = False).head(3)
# Out:
#                      crime_description  victim_age
# 45  DISHONEST EMPLOYEE ATTEMPTED THEFT   60.000000
# 12      BLOCKING DOOR INDUCTION CENTER   54.666667
# 77                            LYNCHING   53.000000

# %%
# Kita menentukan area yang tingkat crime nya tertinggi saat malam hari
# Find the area with the highest number of crimes occurring during nighttime

nighttime_crimes = df[(df['date_occurred'].dt.hour >= 20) | (df['date_occurred'].dt.hour <= 3)]
nighttime_crimes
# Out:
#         division_number date_reported       date_occurred  area    area_name  \
# 0              10304468    2020-01-08 2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02 2020-01-01 03:30:00     1      Central
# 5             200100501    2020-01-02 2020-01-01 00:30:00     1      Central
# 7             200100504    2020-01-04 2020-01-04 00:40:00     1      Central
# 8             200100507    2020-01-04 2020-01-04 02:00:00     1      Central
# ...                 ...           ...                 ...   ...          ...
# 852926        230406516    2023-03-19 2023-03-19 01:22:00     4   Hollenbeck
# 852927        230413421    2023-10-15 2023-10-15 22:45:00     4   Hollenbeck
# 852930        231514016    2023-08-27 2023-08-27 00:30:00    15  N Hollywood
# 852947        230115220    2023-07-02 2023-07-01 00:01:00     1      Central
# 852949        230319786    2023-11-10 2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
# Kita menjumlahkan jumlah crime yang terjadi pada setiap area saat malam hari

nighttime_crimes['area_name'].value_counts()
# Out:
# area_name
# Central        18873
# 77th Street    17568
# Hollywood      15741
# Pacific        15328
# Southwest      14819
# Southeast      14638
# Olympic        14256
# Newton         13843
# N Hollywood    13428
# Rampart        13047
# Wilshire       11665
# Harbor         11623
# Northeast      11379
# West Valley    11351
# West LA        11012
# Van Nuys       10964
# Mission        10813
# Hollenbeck     10425
# Devonshire     10172
# Topanga        10104
# Foothill        8745
# Name: count, dtype: int64

# %%
# Data crime pada setiap jam

hourly_crime = df['date_occurred'].dt.hour.value_counts().sort_index().reset_index()
hourly_crime
# Out:
#     date_occurred  count
# 0               0  35061
# 1               1  25740
# 2               2  21801
# 3               3  19040
# 4               4  16099
# 5               5  14829
# 6               6  19484
# 7               7  21985
# 8               8  31428
# 9               9  30812
# 10             10  36461
# 11             11  36967
# 12             12  57683
# 13             13  38422
# 14             14  41494
# 15             15  44394
# 16             16  44754
# 17             17  49492
# 18             18  50606
# 19             19  46701
# 20             20  47399
# 21             21  43270
# 22             22  41704
# 23             23  35779

# %%
# Menampilkan dalam bar plot data crime setiap jam nya

plt.bar(hourly_crime['date_occurred'], hourly_crime['count'])
# Out:
# <BarContainer object of 24 artists>

# %%
# Kita menampilkan sejumlah crime description yang terjadi pada jam 12

df[df['date_occurred'].dt.hour == 12]['crime_description'].value_counts()
# Out:
# crime_description
# THEFT OF IDENTITY                               9098
# VEHICLE - STOLEN                                4048
# BATTERY - SIMPLE ASSAULT                        3958
# THEFT PLAIN - PETTY ($950 & UNDER)              3785
# BURGLARY                                        2945
#                                                 ...
# DRUGS, TO A MINOR                                  1
# THEFT, COIN MACHINE - GRAND ($950.01 & OVER)       1
# BIGAMY                                             1
# GRAND THEFT / INSURANCE FRAUD                      1
# INCITING A RIOT                                    1
# Name: count, Length: 124, dtype: int64

# %%
# df['crime_description'] == 'THEFT OF IDENTITY': Mengecek baris mana yang memiliki deskripsi 'THEFT OF IDENTITY' 
# (menghasilkan nilai boolean True atau False).
# ~: Operator negasi/Tilde, membalikkan hasil. Jadi, True menjadi False dan sebaliknya.
# df[...]: Memilih baris di mana kondisi di dalamnya bernilai True
# Menghasilkan DataFrame baru no_identity_theft yang tidak mengandung data 
# kejahatan dengan deskripsi "THEFT OF IDENTITY".


no_identity_theft = df[~(df['crime_description'] == 'THEFT OF IDENTITY')]
no_identity_theft
# Out:
#         division_number date_reported       date_occurred  area    area_name  \
# 0              10304468    2020-01-08 2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02 2020-01-01 03:30:00     1      Central
# 2             200110444    2020-04-14 2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01 2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01 2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                 ...   ...          ...
# 852945        231606525    2023-03-22 2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12 2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02 2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05 2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10 2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
# no_identity_theft['date_occurred'].dt.hour
# Mengambil jam dari kolom 'date_occurred', yang diasumsikan bertipe datetime.
# .value_counts()
# Menghitung jumlah kejadian untuk setiap jam (misalnya, jam 0, jam 1, dst.).
# .sort_index()
# Mengurutkan hasil berdasarkan jam (indeks) agar berurutan dari jam 0 hingga jam 23.
# .reset_index()
# Mengatur ulang indeks hasil menjadi default (0, 1, 2, ...) dan menyimpan indeks lama sebagai kolom.

new_hourly_count = no_identity_theft['date_occurred'].dt.hour.value_counts().sort_index().reset_index()

# %%
# Menampilkan dalam bar plot new hourly count dari setiap kemunculan crime 

plt.bar(new_hourly_count['date_occurred'], new_hourly_count['count'])
# Out:
# <BarContainer object of 24 artists>

# %%
no_identity_theft[no_identity_theft['date_occurred'].dt.hour == 12]['crime_description'].value_counts()
# Out:
# crime_description
# VEHICLE - STOLEN                                           4048
# BATTERY - SIMPLE ASSAULT                                   3958
# THEFT PLAIN - PETTY ($950 & UNDER)                         3785
# BURGLARY                                                   2945
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)    2587
#                                                            ...
# DRUGS, TO A MINOR                                             1
# THEFT, COIN MACHINE - GRAND ($950.01 & OVER)                  1
# BIGAMY                                                        1
# GRAND THEFT / INSURANCE FRAUD                                 1
# INCITING A RIOT                                               1
# Name: count, Length: 123, dtype: int64
